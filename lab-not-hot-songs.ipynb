# %%
# import libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# the previous hot songs
hot_songs = pd.read_csv(r"C:\Users\priya\Documents\IRONHACK\Week_6\Day_1\Morning\lab-web-scraping-single-page\hot_songs.csv")
hot_songs
# Out:
#     Unnamed: 0  rank                   song_title  \
# 0            0     1                  Lovin On Me
# 1            1     2                 Cruel Summer
# 2            2     3                       Greedy
# 3            3     4           Paint The Town Red
# 4            4     5        I Remember Everything
# ..         ...   ...                          ...
# 95          95    96                   Tourniquet
# 96          96    97                      Y Lloro
# 97          97    98     Murder On The Dancefloor
# 98          98    99                     Amargura
# 99          99   100  Wildflowers And Wild Horses
#
#                                   artist
# 0                            Jack Harlow
# 1                           Taylor Swift
# 2                             Tate McRae
# 3                               Doja Cat
# 4   Zach Bryan Featuring Kacey Musgraves
# ..                                   ...
# 95                            Zach Bryan
# ...

# %%
hot_songs = hot_songs.drop('Unnamed: 0', axis=1)

# %%
hot_songs
# Out:
#     rank                   song_title                                artist
# 0      1                  Lovin On Me                           Jack Harlow
# 1      2                 Cruel Summer                          Taylor Swift
# 2      3                       Greedy                            Tate McRae
# 3      4           Paint The Town Red                              Doja Cat
# 4      5        I Remember Everything  Zach Bryan Featuring Kacey Musgraves
# ..   ...                          ...                                   ...
# 95    96                   Tourniquet                            Zach Bryan
# 96    97                      Y Lloro                              Junior H
# 97    98     Murder On The Dancefloor                   Sophie Ellis-Bextor
# 98    99                     Amargura                               Karol G
# 99   100  Wildflowers And Wild Horses                         Lainey Wilson
#
# [100 rows x 3 columns]

# %%
hot_songs = hot_songs.rename(columns={'song_title': 'song_title'})
hot_songs
# Out:
#     rank                   song_title                                artist
# 0      1                  Lovin On Me                           Jack Harlow
# 1      2                 Cruel Summer                          Taylor Swift
# 2      3                       Greedy                            Tate McRae
# 3      4           Paint The Town Red                              Doja Cat
# 4      5        I Remember Everything  Zach Bryan Featuring Kacey Musgraves
# ..   ...                          ...                                   ...
# 95    96                   Tourniquet                            Zach Bryan
# 96    97                      Y Lloro                              Junior H
# 97    98     Murder On The Dancefloor                   Sophie Ellis-Bextor
# 98    99                     Amargura                               Karol G
# 99   100  Wildflowers And Wild Horses                         Lainey Wilson
#
# [100 rows x 3 columns]

# %%
hot_songs.to_csv('hot_songs.csv')

# %%
# New dataset not_hot_songs

not_hot_songs = pd.read_csv(r"C:\Users\priya\Documents\IRONHACK\Week_6\Day_1\Afternoon\lab-not-hot-songs\songs.csv")
not_hot_songs
# Out:
#               artist                                    song  duration_ms  \
# 0     Britney Spears                  Oops!...I Did It Again       211160
# 1          blink-182                    All The Small Things       167066
# 2         Faith Hill                                 Breathe       250546
# 3           Bon Jovi                            It's My Life       224493
# 4             *NSYNC                             Bye Bye Bye       200560
# ...              ...                                     ...          ...
# 1995  Jonas Brothers                                  Sucker       181026
# 1996    Taylor Swift                            Cruel Summer       178426
# 1997    Blanco Brown                              The Git Up       200593
# 1998       Sam Smith  Dancing With A Stranger (with Normani)       171029
# 1999     Post Malone                                 Circles       215280
#
#       explicit  year  popularity  danceability  energy  key  loudness  mode  \
# ...

# %%
not_hot_songs.columns
# Out:
# Index(['artist', 'song', 'duration_ms', 'explicit', 'year', 'popularity',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'genre'],
#       dtype='object')

# %%
not_hot_songs = not_hot_songs.drop(columns= ['duration_ms', 'explicit', 'year', 'popularity', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'genre'])

# %%
not_hot_songs
# Out:
#               artist                                    song
# 0     Britney Spears                  Oops!...I Did It Again
# 1          blink-182                    All The Small Things
# 2         Faith Hill                                 Breathe
# 3           Bon Jovi                            It's My Life
# 4             *NSYNC                             Bye Bye Bye
# ...              ...                                     ...
# 1995  Jonas Brothers                                  Sucker
# 1996    Taylor Swift                            Cruel Summer
# 1997    Blanco Brown                              The Git Up
# 1998       Sam Smith  Dancing With A Stranger (with Normani)
# 1999     Post Malone                                 Circles
#
# [2000 rows x 2 columns]

# %%
not_hot_songs = not_hot_songs.rename(columns={'song': 'song_title'})
not_hot_songs
# Out:
#               artist                              song_title
# 0     Britney Spears                  Oops!...I Did It Again
# 1          blink-182                    All The Small Things
# 2         Faith Hill                                 Breathe
# 3           Bon Jovi                            It's My Life
# 4             *NSYNC                             Bye Bye Bye
# ...              ...                                     ...
# 1995  Jonas Brothers                                  Sucker
# 1996    Taylor Swift                            Cruel Summer
# 1997    Blanco Brown                              The Git Up
# 1998       Sam Smith  Dancing With A Stranger (with Normani)
# 1999     Post Malone                                 Circles
#
# [2000 rows x 2 columns]

# %%
# remove duplicates
not_hot_songs = not_hot_songs[~not_hot_songs.isin(hot_songs)].dropna()
not_hot_songs
# Out:
#               artist                              song_title
# 0     Britney Spears                  Oops!...I Did It Again
# 1          blink-182                    All The Small Things
# 2         Faith Hill                                 Breathe
# 3           Bon Jovi                            It's My Life
# 4             *NSYNC                             Bye Bye Bye
# ...              ...                                     ...
# 1995  Jonas Brothers                                  Sucker
# 1996    Taylor Swift                            Cruel Summer
# 1997    Blanco Brown                              The Git Up
# 1998       Sam Smith  Dancing With A Stranger (with Normani)
# 1999     Post Malone                                 Circles
#
# [2000 rows x 2 columns]

# %%
#Combining the songs in combined_songs
combined_songs = pd.concat([hot_songs, not_hot_songs ])
combined_songs
# Out:
#                                        title          artist
# 1          Rockin' Around The Christmas Tree      Brenda Lee
# 2            All I Want For Christmas Is You    Mariah Carey
# 3                           Jingle Bell Rock     Bobby Helms
# 4                             Last Christmas           Wham!
# 5                    A Holly Jolly Christmas       Burl Ives
# ...                                      ...             ...
# 1995                                  Sucker  Jonas Brothers
# 1996                            Cruel Summer    Taylor Swift
# 1997                              The Git Up    Blanco Brown
# 1998  Dancing With A Stranger (with Normani)       Sam Smith
# 1999                                 Circles     Post Malone
#
# [2100 rows x 2 columns]

# %%
combined_songs.isna().sum()
# Out:
# title     0
# artist    0
# dtype: int64

# %%
not_hot_songs.to_csv('not_hot_songs.csv')
